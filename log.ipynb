# %%
import os
targets = os.listdir('logs')
def get_config(target_path):
    with open(os.path.join(target_path, 'config.yaml'), 'r') as fp:
        lines = fp.readlines()
    return lines

for target in targets:
    target_path = os.path.join('logs', target)
    if not 'model_best.pth.tar' in os.listdir(target_path):
        continue
    for meta in get_config(target_path):
        if meta.startswith('trainset_index'):
            print(target, meta)
    print(target)
# Out:
# 20200528_141316.782059
# 20200615_112135.109248
# 20200727_134858.624846 trainset_index: 0
#
# 20200727_134858.624846
# 20200604_133901.915678
# 20200604_134902.414699
# 20200608_152209.707135
# 20200528_140904.466632
# 20200528_141605.665517
# 20200729_164345.980864 trainset_index: 0
#
# 20200729_164345.980864
# 20200604_133322.951519
# 20200727_151029.817267 trainset_index: 0
#
# 20200727_151029.817267
# 20200729_150954.108188 trainset_index: 0
#
# 20200729_150954.108188
# 20200604_105904.310579
# 20200528_123804.556343
# 20200603_105038.403866
# 20200729_142339.448533 trainset_index: 0
#
# 20200729_142339.448533
# 20200528_135404.229092
# 20200729_150648.990749 trainset_index: 0
#
# 20200729_150648.990749
# 20200603_104953.482847
# 20200727_134553.002849 trainset_index: 0
#
# 20200727_134553.002849
# 20200528_143816.689615
# 20200731_160355.787361 trainset_index: 0
#
# 20200731_160355.787361
# 20200727_142534.403674 trainset_index: 0
#
# 20200727_142534.403674
# 20200528_131333.803758
# 20200604_132049.243624
# 20200602_200252.793879
# 20200604_132714.337299
# 20200729_151119.109691 trainset_index: 0
#
# 20200729_151119.109691
# 20200602_224934.778582
# 20200602_193618.438689
# 20200727_140621.261995 trainset_index: 0
#
# 20200727_140621.261995
# 20200604_091347.618848
# 20200730_135144.643172 trainset_index: 0
#
# 20200730_135144.643172
# 20200528_140057.716085
# 20200528_133130.307072
# 20200608_155102.799372
# 20200528_131131.962072
# 20200731_161106.905363 trainset_index: 0
#
# 20200731_161106.905363
# 20200727_142409.200878 trainset_index: 0
#
# 20200727_142409.200878
# 20200731_161608.566224 trainset_index: 0
#
# 20200731_161608.566224
# 20200602_224549.252653
# 20200528_124135.846339
# 20200528_124309.744568
# 20200602_202929.632885
# 20200729_151249.016525 trainset_index: 0
#
# 20200729_151249.016525
# 20200528_141941.720611
# 20200528_134201.068661
# 20200602_225214.242837

# %%
import log

# %%
target_path = log.make_log_path('20200615_112135.109248')

# %%
log.parse_iter(target_path, 40000, target='validation')
# Out:
# {'valid/loss': {'value': '99223.88259447068', 'iter_num': 40000, 'index': 7},
#  'valid/acc': {'value': '0.8436486606291909', 'iter_num': 40000, 'index': 8},
#  'valid/acc_cls': {'value': '0.6617123797709796',
#   'iter_num': 40000,
#   'index': 9},
#  'valid/mean_iu': {'value': '0.5711109875918505',
#   'iter_num': 40000,
#   'index': 10},
#  'valid/fwavacc': {'value': '0.7315928630588059',
#   'iter_num': 40000,
#   'index': 11}}

# %%
valid_result = {}
for i in range(0, 100001, 4000):
    valid_result[str(i)] = log.parse_iter(target_path, i, target='validation')

# %%
valid_result
# Out:
# {'0': {'valid/loss': {'value': '179049.35521808156',
#    'iter_num': 0,
#    'index': 7},
#   'valid/acc': {'value': '0.6009682334043125', 'iter_num': 0, 'index': 8},
#   'valid/acc_cls': {'value': '0.5398672955291617', 'iter_num': 0, 'index': 9},
#   'valid/mean_iu': {'value': '0.3695635542678783', 'iter_num': 0, 'index': 10},
#   'valid/fwavacc': {'value': '0.4892838282714956',
#    'iter_num': 0,
#    'index': 11}},
#  '4000': {'valid/loss': {'value': '102809.13014947412',
#    'iter_num': 4000,
#    'index': 7},
#   'valid/acc': {'value': '0.8317099204037917', 'iter_num': 4000, 'index': 8},
#   'valid/acc_cls': {'value': '0.6757846881468063',
#    'iter_num': 4000,
#    'index': 9},
#   'valid/mean_iu': {'value': '0.5711583095694495',
#    'iter_num': 4000,
#    'index': 10},
#   'valid/fwavacc': {'value': '0.7223922775306688',
#    'iter_num': 4000,
#    'index': 11}},
#  '8000': {'valid/loss': {'value': '101107.5598523145',
#    'iter_num': 8000,
#    'index': 7},
#   'valid/acc': {'value': '0.8367511550372935', 'iter_num': 8000, 'index': 8},
#   'valid/acc_cls': {'value': '0.6794193457350631',
#    'iter_num': 8000,
#    'index': 9},
#   'valid/mean_iu': {'value': '0.5775866787323628',
#    'iter_num': 8000,
#    'index': 10},
#   'valid/fwavacc': {'value': '0.7282101434202348',
#    'iter_num': 8000,
#    'index': 11}},
#  '12000': {'valid/loss': {'value': '103159.06748986882',
#    'iter_num': 12000,
#    'index': 7},
#   'valid/acc': {'value': '0.8333840727168609', 'iter_num': 12000, 'index': 8},
#   'valid/acc_cls': {'value': '0.6770199523143394',
#    'iter_num': 12000,
#    'index': 9},
#   'valid/mean_iu': {'value': '0.5732949678534598',
#    'iter_num': 12000,
#    'index': 10},
#   'valid/fwavacc': {'value': '0.7243231140370809',
#    'iter_num': 12000,
#    'index': 11}},
#  '16000': {'valid/loss': {'value': '99879.26903676732',
#    'iter_num': 16000,
#    'index': 7},
#   'valid/acc': {'value': '0.8393789306681424', 'iter_num': 16000, 'index': 8},
#   'valid/acc_cls': {'value': '0.6726324750483683',
#    'iter_num': 16000,
#    'index': 9},
#   'valid/mean_iu': {'value': '0.5753062361568797',
#    'iter_num': 16000,
#    'index': 10},
#   'valid/fwavacc': {'value': '0.7295896566166471',
#    'iter_num': 16000,
#    'index': 11}},
#  '20000': {'valid/loss': {'value': '100831.25121270654',
#    'iter_num': 20000,
#    'index': 7},
#   'valid/acc': {'value': '0.8386808971670222', 'iter_num': 20000, 'index': 8},
#   'valid/acc_cls': {'value': '0.6688540934321193',
#    'iter_num': 20000,
#    'index': 9},
#   'valid/mean_iu': {'value': '0.5722026514828379',
#    'iter_num': 20000,
#    'index': 10},
#   'valid/fwavacc': {'value': '0.7281274237704393',
#    'iter_num': 20000,
#    'index': 11}},
#  '24000': {'valid/loss': {'value': '101653.79906084193',
#    'iter_num': 24000,
#    'index': 7},
#   'valid/acc': {'value': '0.8394078774885698', 'iter_num': 24000, 'index': 8},
#   'valid/acc_cls': {'value': '0.6670835805531574',
#    'iter_num': 24000,
#    'index': 9},
#   'valid/mean_iu': {'value': '0.5715710188216464',
#    'iter_num': 24000,
#    'index': 10},
#   'valid/fwavacc': {'value': '0.7284980998914828',
#    'iter_num': 24000,
#    'index': 11}},
#  '28000': {'valid/loss': {'value': '101496.26341337316',
#    'iter_num': 28000,
#    'index': 7},
#   'valid/acc': {'value': '0.840795295123748', 'iter_num': 28000, 'index': 8},
#   'valid/acc_cls': {'value': '0.6646385532850416',
#    'iter_num': 28000,
#    'index': 9},
#   'valid/mean_iu': {'value': '0.5709670657015489',
#    'iter_num': 28000,
#    'index': 10},
#   'valid/fwavacc': {'value': '0.7293789654878584',
#    'iter_num': 28000,
#    'index': 11}},
#  '32000': {'valid/loss': {'value': '98932.47435968573',
#    'iter_num': 32000,
#    'index': 7},
#   'valid/acc': {'value': '0.8437264207850166', 'iter_num': 32000, 'index': 8},
#   'valid/acc_cls': {'value': '0.6761930734879334',
#    'iter_num': 32000,
#    'index': 9},
#   'valid/mean_iu': {'value': '0.5812717381701228',
#    'iter_num': 32000,
#    'index': 10},
#   'valid/fwavacc': {'value': '0.7347335177598385',
#    'iter_num': 32000,
#    'index': 11}},
#  '36000': {'valid/loss': {'value': '101060.99468700388',
#    'iter_num': 36000,
#    'index': 7},
#   'valid/acc': {'value': '0.8411616947561662', 'iter_num': 36000, 'index': 8},
#   'valid/acc_cls': {'value': '0.6778888356957448',
#    'iter_num': 36000,
#    'index': 9},
#   'valid/mean_iu': {'value': '0.5802618511484957',
#    'iter_num': 36000,
#    'index': 10},
#   'valid/fwavacc': {'value': '0.7324428654455888',
#    'iter_num': 36000,
#    'index': 11}},
#  '40000': {'valid/loss': {'value': '99223.88259447068',
#    'iter_num': 40000,
#    'index': 7},
#   'valid/acc': {'value': '0.8436486606291909', 'iter_num': 40000, 'index': 8},
#   'valid/acc_cls': {'value': '0.6617123797709796',
#    'iter_num': 40000,
#    'index': 9},
#   'valid/mean_iu': {'value': '0.5711109875918505',
#    'iter_num': 40000,
#    'index': 10},
#   'valid/fwavacc': {'value': '0.7315928630588059',
#    'iter_num': 40000,
#    'index': 11}},
#  '44000': {'valid/loss': {'value': '100832.50113029276',
#    'iter_num': 44000,
#    'index': 7},
#   'valid/acc': {'value': '0.8395568011278775', 'iter_num': 44000, 'index': 8},
#   'valid/acc_cls': {'value': '0.6798966635440096',
#    'iter_num': 44000,
#    'index': 9},
#   'valid/mean_iu': {'value': '0.5802316295031347',
#    'iter_num': 44000,
#    'index': 10},
#   'valid/fwavacc': {'value': '0.7311815058605903',
#    'iter_num': 44000,
#    'index': 11}},
#  '48000': {'valid/loss': {'value': '97994.8746876436',
#    'iter_num': 48000,
#    'index': 7},
#   'valid/acc': {'value': '0.8447180635788861', 'iter_num': 48000, 'index': 8},
#   'valid/acc_cls': {'value': '0.6744840898599427',
#    'iter_num': 48000,
#    'index': 9},
#   'valid/mean_iu': {'value': '0.580937667778825',
#    'iter_num': 48000,
#    'index': 10},
#   'valid/fwavacc': {'value': '0.7353984195255396',
#    'iter_num': 48000,
#    'index': 11}},
#  '52000': {'valid/loss': {'value': '100896.90770309366',
#    'iter_num': 52000,
#    'index': 7},
#   'valid/acc': {'value': '0.8432102713355406', 'iter_num': 52000, 'index': 8},
#   'valid/acc_cls': {'value': '0.6677031434231073',
#    'iter_num': 52000,
#    'index': 9},
#   'valid/mean_iu': {'value': '0.5750211051314604',
#    'iter_num': 52000,
#    'index': 10},
#   'valid/fwavacc': {'value': '0.7324516934680387',
#    'iter_num': 52000,
#    'index': 11}},
#  '56000': {'valid/loss': {'value': '101755.19144851767',
#    'iter_num': 56000,
#    'index': 7},
#   'valid/acc': {'value': '0.8455099728018205', 'iter_num': 56000, 'index': 8},
#   'valid/acc_cls': {'value': '0.6630324743692053',
#    'iter_num': 56000,
#    'index': 9},
#   'valid/mean_iu': {'value': '0.5735186115039417',
#    'iter_num': 56000,
#    'index': 10},
#   'valid/fwavacc': {'value': '0.7337416072673948',
#    'iter_num': 56000,
#    'index': 11}},
#  '60000': {'valid/loss': {'value': '100315.1331800165',
#    'iter_num': 60000,
#    'index': 7},
#   'valid/acc': {'value': '0.8393965812927899', 'iter_num': 60000, 'index': 8},
#   'valid/acc_cls': {'value': '0.6827956575096886',
#    'iter_num': 60000,
#    'index': 9},
#   'valid/mean_iu': {'value': '0.5819599119451169',
#    'iter_num': 60000,
#    'index': 10},
#   'valid/fwavacc': {'value': '0.7315613207297105',
#    'iter_num': 60000,
#    'index': 11}},
#  '64000': {'valid/loss': {'value': '99196.84883550144',
#    'iter_num': 64000,
#    'index': 7},
#   'valid/acc': {'value': '0.845745158067999', 'iter_num': 64000, 'index': 8},
#   'valid/acc_cls': {'value': '0.6712590801459561',
#    'iter_num': 64000,
#    'index': 9},
#   'valid/mean_iu': {'value': '0.5795587167615959',
#    'iter_num': 64000,
#    'index': 10},
#   'valid/fwavacc': {'value': '0.7357693254780874',
#    'iter_num': 64000,
#    'index': 11}},
#  '68000': {'valid/loss': {'value': '100663.79610863344',
#    'iter_num': 68000,
#    'index': 7},
#   'valid/acc': {'value': '0.8368098850556236', 'iter_num': 68000, 'index': 8},
#   'valid/acc_cls': {'value': '0.699384718876937',
#    'iter_num': 68000,
#    'index': 9},
#   'valid/mean_iu': {'value': '0.5898390838676894',
#    'iter_num': 68000,
#    'index': 10},
#   'valid/fwavacc': {'value': '0.731749336603959',
#    'iter_num': 68000,
#    'index': 11}},
#  '72000': {'valid/loss': {'value': '101388.214561748',
#    'iter_num': 72000,
#    'index': 7},
#   'valid/acc': {'value': '0.8423437052232059', 'iter_num': 72000, 'index': 8},
#   'valid/acc_cls': {'value': '0.6745594724638175',
#    'iter_num': 72000,
#    'index': 9},
#   'valid/mean_iu': {'value': '0.5790237247722663',
#    'iter_num': 72000,
#    'index': 10},
#   'valid/fwavacc': {'value': '0.732991234473412',
#    'iter_num': 72000,
#    'index': 11}},
#  '76000': {'valid/loss': {'value': '100911.85087805764',
#    'iter_num': 76000,
#    'index': 7},
#   'valid/acc': {'value': '0.8417420234272187', 'iter_num': 76000, 'index': 8},
#   'valid/acc_cls': {'value': '0.6765446188434997',
#    'iter_num': 76000,
#    'index': 9},
#   'valid/mean_iu': {'value': '0.5798548459418583',
#    'iter_num': 76000,
#    'index': 10},
#   'valid/fwavacc': {'value': '0.7327730843604782',
#    'iter_num': 76000,
#    'index': 11}},
#  '80000': {'valid/loss': {'value': '98888.20045022403',
#    'iter_num': 80000,
#    'index': 7},
#   'valid/acc': {'value': '0.8428332818383202', 'iter_num': 80000, 'index': 8},
#   'valid/acc_cls': {'value': '0.6757872745869691',
#    'iter_num': 80000,
#    'index': 9},
#   'valid/mean_iu': {'value': '0.5802550636588325',
#    'iter_num': 80000,
#    'index': 10},
#   'valid/fwavacc': {'value': '0.7337381609062253',
#    'iter_num': 80000,
#    'index': 11}},
#  '84000': {'valid/loss': {'value': '97908.42313176935',
#    'iter_num': 84000,
#    'index': 7},
#   'valid/acc': {'value': '0.8430558755436045', 'iter_num': 84000, 'index': 8},
#   'valid/acc_cls': {'value': '0.6916983008451305',
#    'iter_num': 84000,
#    'index': 9},
#   'valid/mean_iu': {'value': '0.5907577510626844',
#    'iter_num': 84000,
#    'index': 10},
#   'valid/fwavacc': {'value': '0.737012548174953',
#    'iter_num': 84000,
#    'index': 11}},
#  '88000': {'valid/loss': {'value': '100286.1384714708',
#    'iter_num': 88000,
#    'index': 7},
#   'valid/acc': {'value': '0.8447490809435513', 'iter_num': 88000, 'index': 8},
#   'valid/acc_cls': {'value': '0.6702424802082343',
#    'iter_num': 88000,
#    'index': 9},
#   'valid/mean_iu': {'value': '0.5780358036455164',
#    'iter_num': 88000,
#    'index': 10},
#   'valid/fwavacc': {'value': '0.7345438482906835',
#    'iter_num': 88000,
#    'index': 11}},
#  '92000': {'valid/loss': {'value': '100454.85028272007',
#    'iter_num': 92000,
#    'index': 7},
#   'valid/acc': {'value': '0.8441752035987569', 'iter_num': 92000, 'index': 8},
#   'valid/acc_cls': {'value': '0.6720519290264144',
#    'iter_num': 92000,
#    'index': 9},
#   'valid/mean_iu': {'value': '0.5788211619359611',
#    'iter_num': 92000,
#    'index': 10},
#   'valid/fwavacc': {'value': '0.7343417302965316',
#    'iter_num': 92000,
#    'index': 11}},
#  '96000': {'valid/loss': {'value': '100696.28171837139',
#    'iter_num': 96000,
#    'index': 7},
#   'valid/acc': {'value': '0.8358563535353717', 'iter_num': 96000, 'index': 8},
#   'valid/acc_cls': {'value': '0.6965112029983062',
#    'iter_num': 96000,
#    'index': 9},
#   'valid/mean_iu': {'value': '0.5873058355476121',
#    'iter_num': 96000,
#    'index': 10},
#   'valid/fwavacc': {'value': '0.730270233376335',
#    'iter_num': 96000,
#    'index': 11}},
#  '100000': {'valid/loss': {'value': '101045.11482410126',
#    'iter_num': 100000,
#    'index': 7},
#   'valid/acc': {'value': '0.8400322817226145', 'iter_num': 100000, 'index': 8},
#   'valid/acc_cls': {'value': '0.6802825213954746',
#    'iter_num': 100000,
#    'index': 9},
#   'valid/mean_iu': {'value': '0.5808803572226103',
#    'iter_num': 100000,
#    'index': 10},
#   'valid/fwavacc': {'value': '0.7317439425979828',
#    'iter_num': 100000,
#    'index': 11}}}

# %%
for item in sorted(list(valid_result.values()), key=lambda item: item['valid/mean_iu']['value'], reverse=True):
    print(item['valid/mean_iu'])
# Out:
# {'value': '0.5907577510626844', 'iter_num': 84000, 'index': 10}
# {'value': '0.5898390838676894', 'iter_num': 68000, 'index': 10}
# {'value': '0.5873058355476121', 'iter_num': 96000, 'index': 10}
# {'value': '0.5819599119451169', 'iter_num': 60000, 'index': 10}
# {'value': '0.5812717381701228', 'iter_num': 32000, 'index': 10}
# {'value': '0.580937667778825', 'iter_num': 48000, 'index': 10}
# {'value': '0.5808803572226103', 'iter_num': 100000, 'index': 10}
# {'value': '0.5802618511484957', 'iter_num': 36000, 'index': 10}
# {'value': '0.5802550636588325', 'iter_num': 80000, 'index': 10}
# {'value': '0.5802316295031347', 'iter_num': 44000, 'index': 10}
# {'value': '0.5798548459418583', 'iter_num': 76000, 'index': 10}
# {'value': '0.5795587167615959', 'iter_num': 64000, 'index': 10}
# {'value': '0.5790237247722663', 'iter_num': 72000, 'index': 10}
# {'value': '0.5788211619359611', 'iter_num': 92000, 'index': 10}
# {'value': '0.5780358036455164', 'iter_num': 88000, 'index': 10}
# {'value': '0.5775866787323628', 'iter_num': 8000, 'index': 10}
# {'value': '0.5753062361568797', 'iter_num': 16000, 'index': 10}
# {'value': '0.5750211051314604', 'iter_num': 52000, 'index': 10}
# {'value': '0.5735186115039417', 'iter_num': 56000, 'index': 10}
# {'value': '0.5732949678534598', 'iter_num': 12000, 'index': 10}
# {'value': '0.5722026514828379', 'iter_num': 20000, 'index': 10}
# {'value': '0.5715710188216464', 'iter_num': 24000, 'index': 10}
# {'value': '0.5711583095694495', 'iter_num': 4000, 'index': 10}
# {'value': '0.5711109875918505', 'iter_num': 40000, 'index': 10}
# {'value': '0.5709670657015489', 'iter_num': 28000, 'index': 10}
# {'value': '0.3695635542678783', 'iter_num': 0, 'index': 10}

# %%
for item in sorted(list(valid_result.values()), key=lambda item: item['valid/acc']['value'], reverse=True):
    print(item['valid/acc'])
# Out:
# {'value': '0.845745158067999', 'iter_num': 64000, 'index': 8}
# {'value': '0.8455099728018205', 'iter_num': 56000, 'index': 8}
# {'value': '0.8447490809435513', 'iter_num': 88000, 'index': 8}
# {'value': '0.8447180635788861', 'iter_num': 48000, 'index': 8}
# {'value': '0.8441752035987569', 'iter_num': 92000, 'index': 8}
# {'value': '0.8437264207850166', 'iter_num': 32000, 'index': 8}
# {'value': '0.8436486606291909', 'iter_num': 40000, 'index': 8}
# {'value': '0.8432102713355406', 'iter_num': 52000, 'index': 8}
# {'value': '0.8430558755436045', 'iter_num': 84000, 'index': 8}
# {'value': '0.8428332818383202', 'iter_num': 80000, 'index': 8}
# {'value': '0.8423437052232059', 'iter_num': 72000, 'index': 8}
# {'value': '0.8417420234272187', 'iter_num': 76000, 'index': 8}
# {'value': '0.8411616947561662', 'iter_num': 36000, 'index': 8}
# {'value': '0.840795295123748', 'iter_num': 28000, 'index': 8}
# {'value': '0.8400322817226145', 'iter_num': 100000, 'index': 8}
# {'value': '0.8395568011278775', 'iter_num': 44000, 'index': 8}
# {'value': '0.8394078774885698', 'iter_num': 24000, 'index': 8}
# {'value': '0.8393965812927899', 'iter_num': 60000, 'index': 8}
# {'value': '0.8393789306681424', 'iter_num': 16000, 'index': 8}
# {'value': '0.8386808971670222', 'iter_num': 20000, 'index': 8}
# {'value': '0.8368098850556236', 'iter_num': 68000, 'index': 8}
# {'value': '0.8367511550372935', 'iter_num': 8000, 'index': 8}
# {'value': '0.8358563535353717', 'iter_num': 96000, 'index': 8}
# {'value': '0.8333840727168609', 'iter_num': 12000, 'index': 8}
# {'value': '0.8317099204037917', 'iter_num': 4000, 'index': 8}
# {'value': '0.6009682334043125', 'iter_num': 0, 'index': 8}
